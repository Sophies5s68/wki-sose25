# %%
import CNN_dataset
from wettbewerb import load_references, get_3montages
import os
import importlib

# %%
importlib.reload(CNN_dataset)
train_folder = train_folder = "../shared_data/training"
files = [f for f in os.listdir(train_folder) if f.endswith('.mat')]
n_files = len(files)
print(f"found {n_files} files")
for i in range(0,n_files,100):
    ids, channels, data, sampling_frequencies, reference_systems, eeg_labels = load_references(train_folder,i)
    CNN_dataset.create_cnn_dataset_map(ids, channels, data, sampling_frequencies, reference_systems, eeg_labels,i)
    print(f"created dataset {i}")
# Out:
# found 6213 files
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 0
# 100	 Dateien wurden geladen.
# /home/jupyter-wki_team_3/wki-sose25/features.py:101: RuntimeWarning: invalid value encountered in divide
#   psd_norm = spectrum / np.sum(spectrum)
# Dataset mit Maps erstellt
# created dataset 100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 1900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 2900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 3900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 4900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5100
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5200
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5300
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5400
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5500
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5600
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5700
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5800
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 5900
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 6000
# 100	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 6100
# 13	 Dateien wurden geladen.
# Dataset mit Maps erstellt
# created dataset 6200
